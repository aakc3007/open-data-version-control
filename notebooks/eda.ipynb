# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../src/data/iris_train.csv')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                6.1               2.8                4.7               1.2
# 1                5.7               3.8                1.7               0.3
# 2                7.7               2.6                6.9               2.3
# 3                6.0               2.9                4.5               1.5
# 4                6.8               2.8                4.8               1.4
#
#    target
# 0       1
# 1       0
# 2       2
# 3       1
# 4       1

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         105.000000        105.000000         105.000000
# mean            5.776190          3.075238           3.601905
# std             0.838328          0.460305           1.813888
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.500000
# 50%             5.700000          3.000000           4.200000
# 75%             6.300000          3.400000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        105.000000  105.000000
# mean           1.133333    0.923810
# std            0.777158    0.828521
# min            0.100000    0.000000
# 25%            0.200000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
print("Class distribution:\n", df['target'].value_counts())
# Out:
# Class distribution:
#  target
# 0    40
# 1    33
# 2    32
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue='target', vars=df.columns[:-1])
plt.suptitle("Pairplot of Iris training features", y=1.02)
plt.show()
